# %%
import pandas as pd

# %%
# Load the XLSX file
xlsx_file = 'your_file.xlsx'
df = pd.read_excel(xlsx_file)

# Save to CSV file
csv_file = 'your_file.csv'
df.to_csv(csv_file, index=False)

# %%
# Load the XLSX file
xlsx_file = 'Data/Other ischaemic diseases male.xlsx'
ischaemic_male = pd.read_excel(xlsx_file)


# Save to CSV file
csv_file = 'Data/other ischaemic dieseases male.csv'
ischaemic_male.to_csv(csv_file, index=False)

# %%
# Load the XLSX file
xlsx_file = 'Data/Other ischaemic females.xlsx'
ischaemic_female = pd.read_excel(xlsx_file)


# Save to CSV file
csv_file = 'Data/other ischaemic females.csv'
ischaemic_female.to_csv(csv_file, index=False)

# %%
df_ischaemic_male = pd.read_csv('Data/other ischaemic dieseases male.csv')

# %%
df_ischaemic_female = pd.read_csv('Data/other ischaemic females.csv')

# %%
df_ischaemic_male
# Out:
#            country    2012    2013    2014    2015    2016   2017   2018  \
# 0          Belgium    5.16    5.21    5.00    5.22    4.35   4.14   4.96
# 1         Bulgaria   24.09   22.85   22.20   22.61   21.95  24.99  22.40
# 2          Czechia   30.36   33.52   32.27   30.88   27.71  27.79  29.38
# 3          Denmark    7.98    7.65    8.70    7.18    7.99   7.38   6.34
# 4          Germany    9.93    9.56    9.46   10.09    9.47   9.57   9.49
# 5          Estonia   58.64   48.22   51.71   37.97   43.95  38.57  37.43
# 6          Ireland   23.06   21.11   22.36   19.49   19.19  16.41  18.74
# 7           Greece   16.10   17.17   16.70   21.26   20.12  17.24  16.17
# 8            Spain    7.67    8.30    7.66    7.67    7.67   7.45   7.84
# 9           France    4.93    5.04    4.97    5.33    5.14   5.49   5.24
# 10         Croatia   15.14   14.08   15.69   15.30   15.23  12.71  10.74
# 11           Italy    6.62    6.64    5.66    6.15    5.86   5.70   5.36
# ...

# %%
df_ischaemic_female
# Out:
#            country   2012   2013   2014   2015   2016   2017   2018   2019  \
# 0          Belgium   1.16   1.17   1.15   1.53   1.29   1.41   1.20   1.08
# 1         Bulgaria   6.82   6.50   5.95   6.49   5.93   7.91   6.71   6.45
# 2          Czechia   7.49   8.64   7.05   7.49   6.30   6.31   6.61   6.19
# 3          Denmark   1.66   2.80   2.08   2.61   1.76   2.07   1.49   1.98
# 4          Germany   2.29   2.29   2.14   2.36   2.14   2.08   2.04   2.04
# 5          Estonia   8.10  10.50   7.18   7.03   6.12   8.38   4.56   3.65
# 6          Ireland   4.61   4.84   5.22   5.98   3.96   3.81   3.16   4.09
# 7           Greece   3.47   4.23   3.43   4.11   4.52   3.58   4.29   3.32
# 8            Spain   1.39   1.36   1.32   1.40   1.45   1.35   1.40   1.43
# 9           France   0.94   0.94   1.00   0.88   0.84   0.95   1.12   1.16
# 10         Croatia   4.87   4.45   4.77   4.68   3.52   3.38   3.21   3.49
# ...

# %%
df_ischaemic_female['country'].value_counts()
# Out:
# country
# Belgium           1
# Finland           1
# Austria           1
# Poland            1
# Portugal          1
# Romania           1
# Slovenia          1
# Slovakia          1
# Sweden            1
# Bulgaria          1
# Iceland           1
# Liechtenstein     1
# Norway            1
# Switzerland       1
# United Kingdom    1
# Serbia            1
# Netherlands       1
# Malta             1
# Hungary           1
# Luxembourg        1
# Lithuania         1
# Latvia            1
# Cyprus            1
# Italy             1
# Croatia           1
# France            1
# Spain             1
# Greece            1
# Ireland           1
# Estonia           1
# Germany           1
# Denmark           1
# Czechia           1
# Türkiye           1
# Name: count, dtype: int64

# %%
df_ischaemic_f_m = pd.merge(df_ischaemic_male, df_ischaemic_female, on='country', how='left')

# %%
df_ischaemic_f_m
# Out:
#            country  2012_x  2013_x  2014_x  2015_x  2016_x  2017_x  2018_x  \
# 0          Belgium    5.16    5.21    5.00    5.22    4.35    4.14    4.96
# 1         Bulgaria   24.09   22.85   22.20   22.61   21.95   24.99   22.40
# 2          Czechia   30.36   33.52   32.27   30.88   27.71   27.79   29.38
# 3          Denmark    7.98    7.65    8.70    7.18    7.99    7.38    6.34
# 4          Germany    9.93    9.56    9.46   10.09    9.47    9.57    9.49
# 5          Estonia   58.64   48.22   51.71   37.97   43.95   38.57   37.43
# 6          Ireland   23.06   21.11   22.36   19.49   19.19   16.41   18.74
# 7           Greece   16.10   17.17   16.70   21.26   20.12   17.24   16.17
# 8            Spain    7.67    8.30    7.66    7.67    7.67    7.45    7.84
# 9           France    4.93    5.04    4.97    5.33    5.14    5.49    5.24
# 10         Croatia   15.14   14.08   15.69   15.30   15.23   12.71   10.74
# ...

# %%
# Combine sex columns
df_ischaemic_f_m['sex'] = df_ischaemic_f_m['sex_y'].combine(df_ischaemic_f_m['sex_x'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Combine sex columns
# ----> 2 df_ischaemic_f_m['sex'] = df_ischaemic_f_m['sex_y'].combine(df_ischaemic_f_m['sex_x'])
#
# TypeError: combine() missing 1 required positional argument: 'func'

# %%
df_ischaemic_f_m
# Out:
#            country  2012_x  2013_x  2014_x  2015_x  2016_x  2017_x  2018_x  \
# 0          Belgium    5.16    5.21    5.00    5.22    4.35    4.14    4.96
# 1         Bulgaria   24.09   22.85   22.20   22.61   21.95   24.99   22.40
# 2          Czechia   30.36   33.52   32.27   30.88   27.71   27.79   29.38
# 3          Denmark    7.98    7.65    8.70    7.18    7.99    7.38    6.34
# 4          Germany    9.93    9.56    9.46   10.09    9.47    9.57    9.49
# 5          Estonia   58.64   48.22   51.71   37.97   43.95   38.57   37.43
# 6          Ireland   23.06   21.11   22.36   19.49   19.19   16.41   18.74
# 7           Greece   16.10   17.17   16.70   21.26   20.12   17.24   16.17
# 8            Spain    7.67    8.30    7.66    7.67    7.67    7.45    7.84
# 9           France    4.93    5.04    4.97    5.33    5.14    5.49    5.24
# 10         Croatia   15.14   14.08   15.69   15.30   15.23   12.71   10.74
# ...

# %%
df_combined = pd.concat([df_ischaemic_female, df_ischaemic_male], ignore_index=True)

# %%
df_combined.head()
# Out:
#     country  2012  2013  2014  2015  2016  2017  2018  2019  2020  2021  \
# 0   Belgium  1.16  1.17  1.15  1.53  1.29  1.41  1.20  1.08  0.97  1.24
# 1  Bulgaria  6.82  6.50  5.95  6.49  5.93  7.91  6.71  6.45  8.13  9.50
# 2   Czechia  7.49  8.64  7.05  7.49  6.30  6.31  6.61  6.19  6.01  5.96
# 3   Denmark  1.66  2.80  2.08  2.61  1.76  2.07  1.49  1.98  1.47  1.99
# 4   Germany  2.29  2.29  2.14  2.36  2.14  2.08  2.04  2.04  1.89  1.99
#
#       sex
# 0  Female
# 1  Female
# 2  Female
# 3  Female
# 4  Female

# %%
df_combined.tail()
# Out:
#            country   2012   2013   2014   2015   2016   2017   2018   2019  \
# 63          Norway   9.41   8.31   7.95   7.79   8.36   7.14   7.76   7.49
# 64     Switzerland   8.87   7.45   8.75   7.35   6.92   6.36   5.90   5.51
# 65  United Kingdom  19.69  19.45  19.08  19.16  18.64  18.66  18.09    NaN
# 66          Serbia  12.73  11.87  12.97  12.78  11.96  11.26  12.89  12.07
# 67         Türkiye  11.76  14.16  13.77  13.90  14.15  14.84  12.92  12.28
#
#      2020   2021   sex
# 63   8.13   6.57  Male
# 64   5.83   5.25  Male
# 65    NaN    NaN  Male
# 66  11.85  12.14  Male
# 67  15.10  13.89  Male

# %%
df_combined.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 63    False
# 64    False
# 65    False
# 66    False
# 67    False
# Length: 68, dtype: bool
