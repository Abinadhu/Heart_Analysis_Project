# %%
#Heart Project 

import pandas as pd
import seaborn as sns
import matplotlib 
from matplotlib import pyplot as plt
import numpy as np 
from scipy import stats

# %%
heart = pd.read_csv('heart_attack_prediction_dataset.csv', delimiter= ',')
heart.head()
heart.columns
# Out:
# Index(['Patient ID', 'Age', 'Sex', 'Cholesterol', 'Blood Pressure',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk'],
#       dtype='object')

# %%
heart.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  8763.000000  8763.000000  8763.000000  8763.000000     8763.000000
# mean     53.707977   259.877211    75.021682     0.652288        0.492982
# std      21.249509    80.863276    20.550948     0.476271        0.499979
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      54.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   330.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8763.000000  8763.000000          8763.000000              8763.000000
# mean      0.896839     0.501426             0.598083                10.014284
# ...

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
heart['Country'].value_counts()
# Out:
# Country
# Germany           477
# Argentina         471
# Brazil            462
# United Kingdom    457
# Australia         449
# Nigeria           448
# France            446
# Canada            440
# China             436
# New Zealand       435
# Japan             433
# Italy             431
# Spain             430
# Colombia          429
# Thailand          428
# South Africa      425
# Vietnam           425
# United States     420
# India             412
# South Korea       409
# Name: count, dtype: int64

# %%
heart['Country'].unique()
# Out:
# array(['Argentina', 'Canada', 'France', 'Thailand', 'Germany', 'Japan',
#        'Brazil', 'South Africa', 'United States', 'Vietnam', 'China',
#        'Italy', 'Spain', 'India', 'Nigeria', 'New Zealand', 'South Korea',
#        'Australia', 'Colombia', 'United Kingdom'], dtype=object)

# %%
wlb = pd.read_csv('Cities with the Best Work-Life Balance 2022.csv', delimiter= ',')

# %%
wlb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   2022                              100 non-null    int64
#  1   2021                              100 non-null    object
#  2   City                              100 non-null    object
#  3   Country                           100 non-null    object
#  4   Remote Jobs                       100 non-null    object
#  5   Overworked Population             100 non-null    object
#  6   Minimum Vacations Offered (Days)  100 non-null    int64
#  7   Vacations Taken (Days)            100 non-null    object
#  8   Unemployment                      100 non-null    float64
#  9   Multiple Jobholders               100 non-null    object
#  10  Inflation                         100 non-null    object
# ...

# %%
wlb.head()
# Out:
#    2022 2021        City      Country Remote Jobs Overworked Population  \
# 0     1    2        Oslo       Norway      41.72%                11.20%
# 1     2    -        Bern  Switzerland      44.86%                11.40%
# 2     3    1    Helsinki      Finland      38.92%                12.70%
# 3     4    3      Zurich  Switzerland      44.86%                11.90%
# 4     5    5  Copenhagen      Denmark      41.42%                10.50%
#
#    Minimum Vacations Offered (Days) Vacations Taken (Days)  Unemployment  \
# 0                                25                     25          94.7
# 1                                20                     25          99.8
# 2                                25                     30          89.3
# 3                                20                     25          99.2
# 4                                25                     28          94.8
#
#   Multiple Jobholders  ... Healthcare Access to Mental Healthcare  \
# ...

# %%
wlb['Country']
# Out:
# 0           Norway
# 1      Switzerland
# 2          Finland
# 3      Switzerland
# 4          Denmark
#           ...
# 95        Thailand
# 96          Brazil
# 97        Malaysia
# 98             UAE
# 99    South Africa
# Name: Country, Length: 100, dtype: object

# %%
wlb['Country'].unique()
wlb['Country'].value_counts()
# Out:
# Country
# USA             51
# Germany          9
# UK               4
# Canada           4
# Switzerland      3
# Spain            2
# Australia        2
# Austria          2
# Norway           1
# South Korea      1
# Hong Kong        1
# Argentina        1
# Uruguay          1
# Hungary          1
# Thailand         1
# Brazil           1
# Malaysia         1
# UAE              1
# Italy            1
# Ireland          1
# Portugal         1
# Singapore        1
# Belgium          1
# France           1
# New Zealand      1
# Japan            1
# Netherlands      1
# Sweden           1
# Denmark          1
# Finland          1
# South Africa     1
# Name: count, dtype: int64

# %%
heart['Country'].value_counts()
# Out:
# Country
# Germany           477
# Argentina         471
# Brazil            462
# United Kingdom    457
# Australia         449
# Nigeria           448
# France            446
# Canada            440
# China             436
# New Zealand       435
# Japan             433
# Italy             431
# Spain             430
# Colombia          429
# Thailand          428
# South Africa      425
# Vietnam           425
# United States     420
# India             412
# South Korea       409
# Name: count, dtype: int64

# %%
merged_df = pd.merge(heart, wlb, on= 'Country', how='left') # Left

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14778 entries, 0 to 14777
# Data columns (total 49 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Patient ID                        14778 non-null  object
#  1   Age                               14778 non-null  int64
#  2   Sex                               14778 non-null  object
#  3   Cholesterol                       14778 non-null  int64
#  4   Blood Pressure                    14778 non-null  object
#  5   Heart Rate                        14778 non-null  int64
#  6   Diabetes                          14778 non-null  int64
#  7   Family History                    14778 non-null  int64
#  8   Smoking                           14778 non-null  int64
#  9   Obesity                           14778 non-null  int64
#  10  Alcohol Consumption               14778 non-null  int64
# ...

# %%
merged_df.columns = merged_df.columns.str.replace( ' ', '_').str.lower()

# %%
merged_df.reset_index(drop=True, inplace=True)

# %%
merged_df
# Out:
#        age     sex  cholesterol blood_pressure  diabetes  family_history  \
# 0       67    Male          208         158/88         0               0
# 1       21    Male          389         165/93         1               1
# 2       21    Male          389         165/93         1               1
# 3       21    Male          389         165/93         1               1
# 4       21    Male          389         165/93         1               1
# ...    ...     ...          ...            ...       ...             ...
# 14772   28  Female          120        157/102         1               0
# 14773   28  Female          120        157/102         1               0
# 14774   28  Female          120        157/102         1               0
# 14775   47    Male          250         161/75         0               1
# 14776   36    Male          178         119/67         1               0
#
#        smoking  obesity  alcohol_consumption  exercise_hours_per_week  ...  \
# ...

# %%
merged_df.dropna(inplace=True)
merged_df.isnull().sum()
# Out:
# patient_id                          0
# age                                 0
# sex                                 0
# cholesterol                         0
# blood_pressure                      0
# heart_rate                          0
# diabetes                            0
# family_history                      0
# smoking                             0
# obesity                             0
# alcohol_consumption                 0
# exercise_hours_per_week             0
# diet                                0
# previous_heart_problems             0
# medication_use                      0
# stress_level                        0
# sedentary_hours_per_day             0
# income                              0
# bmi                                 0
# triglycerides                       0
# physical_activity_days_per_week     0
# sleep_hours_per_day                 0
# country                             0
# continent                           0
# hemisphere                          0
# ...

# %%
# Average risk of a heart attack in a population between 18 and 70 years old

merged_age = merged_df[(merged_df['age'] >= 18 & (merged_df['age']<= 70))]

# %%
age_groups = [18, 25, 35, 45, 55, 65, 70]
age_labels = ['18-24', '25-34', '35-44', '45-54', '55-64', '65-70']
merged_sex_age['age_groups'] = pd.cut(merged_sex_age['age'], bins=age_groups,labels =age_labels, right=False)

# %%
grouped_sex_age = merged_sex_age.groupby(['age_groups','sex'])['heart_attack_risk'].mean().reset_index()

# %%
# merged_sex_age = merged_df.groupby(['age', 'sex']).agg({'heart_attack_risk': 'mean'}).reset_index()

# merged_sex_age.describe()
# Out:
#               age  heart_attack_risk
# count  146.000000         146.000000
# mean    54.000000           0.355924
# std     21.143842           0.123394
# min     18.000000           0.062500
# 25%     36.000000           0.275866
# 50%     54.000000           0.355196
# 75%     72.000000           0.424882
# max     90.000000           0.761905

# %%
sex_colors = {'Male': 'blue', 'Female':'salmon'}

plt.figure(figsize=(12,8))
age_sex = sns.barplot(data= merged_sex_age, x= 'age_groups', y= 'heart_attack_risk', hue= 'sex', palette= sex_colors)

age_sex.set_title('Heart Attack Risk by Age and Sex')
age_sex.set_xlabel('Age', fontsize= 15)
age_sex.set_ylabel( 'Heart Attack Risk (%)', fontsize=15)

plt.legend(title='Sex', title_fontsize= '13', loc ='upper right', fontsize= '11')
plt.xticks(rotation= 30)

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plt.figure(figsize=(12,8))
# age_country = sns.barplot(data= merged_sex_age, x= 'age_groups', y= 'country', hue= 'sex', palette= 'muted')

# # age_sex.set_title('Heart Attack Risk by Age and Sex')
# # age_sex.set_xlabel('Age', fontsize= 15)
# # age_sex.set_ylabel( 'Heart Attack Risk', fontsize=15)

# plt.legend(title='Sex', title_fontsize= '13', loc ='upper right', fontsize= '11')
# plt.xticks(rotation= 30)

# plt.tight_layout()
# plt.show

# %%
merged_df['sex'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.violinplot(x = 'Sex', y= 'Age', data= merged_df, palette= 'muted')
# Out:
# C:\Users\gisac\AppData\Local\Temp\ipykernel_25128\2382043804.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Sex', y= 'Age', data= merged_df, palette= 'muted')
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
heart_attack_count = merged_df.groupby('Sex')['Heart Attack Risk'].value_counts().unstack(fill_value=0)
heart_attack_count.columns = ['No Heart Attack', 'Heart Attack']
heart_attack_count
# Out:
#         No Heart Attack  Heart Attack
# Sex
# Female             2891          1600
# Male               6580          3707

# %%
heart_attack_count.plot(kind='bar', stacked=True, color=['blue', 'red']) # try to do with the percentages
# Out:
# <Axes: xlabel='Sex'>

# %%
sns.violinplot(x = 'Sex', y= 'Heart Attack Risk', data= merged_df, palette= 'muted')
# Out:
# C:\Users\gisac\AppData\Local\Temp\ipykernel_20424\1670292174.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x = 'Sex', y= 'Heart Attack Risk', data= merged_df, palette= 'muted')
# <Axes: xlabel='Sex', ylabel='Heart Attack Risk'>

# %%
fem_risk = (1600/14778)*100
fem_risk
# Out:
# 10.826904858573554

# %%
fem_no_risk = (2891/14778)*100
fem_no_risk
# Out:
# 19.562863716335094

# %%
male_risk = (3707/14778)*100
male_risk
# Out:
# 25.084585194207605

# %%
male_no_risk = (6580/14778)*100
male_no_risk
# Out:
# 44.525646230883744

# %%
wlb_risk = merged_df.sort_values(by='total_score', ascending=True)

plt.figure(figsize=(12,8))
countries = sns.boxplot(data= wlb_risk, x= 'country', y= 'total_score', palette= 'muted')

countries.set_title('WLB scored by Country', fontsize=18)
countries.set_xlabel('Country', fontsize= 15)
countries.set_ylabel( 'WLB Score', fontsize=15)

plt.xticks(rotation= 30)

plt.tight_layout()
plt.show
# Out:
# C:\Users\gisac\AppData\Local\Temp\ipykernel_20424\150518483.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   countries = sns.boxplot(data= wlb_risk, x= 'country', y= 'total_score', palette= 'muted')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
merged_df.describe()['total_score']
# Out:
# count    11751.000000
# mean        86.711800
# std         10.214264
# min         50.000000
# 25%         84.930000
# 50%         90.920000
# 75%         92.450000
# max         95.510000
# Name: total_score, dtype: float64

# %%
#wlb_risk = merged_df.sort_values(by='total_score', ascending=True)
mean_wlb = merged_df['total_score'].mean()

plt.figure(figsize=(12,8))
countries = sns.barplot(data= wlb_risk, x= 'country', y= 'total_score', palette= 'muted')

countries.set_ylim(40,100)

countries.axhline(mean_wlb, color='black', linestyle='--', label=f'Mean:{mean_wlb:.2f}')

countries.set_title('WLB scored by Country', fontsize=18)
countries.set_xlabel('Country', fontsize= 15)
countries.set_ylabel( 'WLB Score', fontsize=15)

plt.xticks(rotation= 30)

plt.tight_layout()
plt.show
# Out:
# C:\Users\gisac\AppData\Local\Temp\ipykernel_20424\1336310690.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   countries = sns.barplot(data= wlb_risk, x= 'country', y= 'total_score', palette= 'muted')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
merged_df['country'].value_counts()
# Out:
# country
# Germany         4293
# Canada          1760
# Australia        898
# Spain            860
# Argentina        471
# Brazil           462
# France           446
# New Zealand      435
# Japan            433
# Italy            431
# Thailand         428
# South Africa     425
# South Korea      409
# Name: count, dtype: int64

# %%
mean_har = merged_df['heart_attack_risk'].mean()  # har = heart attack risk

plt.figure(figsize=(12,8))
countries = sns.barplot(data= wlb_risk, x= 'country', y= 'heart_attack_risk', palette= 'muted')

countries.set_ylim(0.2,0.5)

countries.axhline(mean_har, color='black', linestyle='--', label=f'Mean:{mean_wlb:.2f}')

countries.set_title('Heart Attack Risk by Country', fontsize=18)
countries.set_xlabel('Country', fontsize= 15)
countries.set_ylabel( 'Heart Attack Risk', fontsize=15)

plt.xticks(rotation= 30)

plt.tight_layout()
plt.show
# Out:
# C:\Users\gisac\AppData\Local\Temp\ipykernel_20424\207684735.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   countries = sns.barplot(data= wlb_risk, x= 'country', y= 'heart_attack_risk', palette= 'muted')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
merged_df = pd.DataFrame(merged_df)

# %%
merged_df.columns
# Out:
# Index(['patient_id', 'age', 'sex', 'cholesterol', 'blood_pressure',
#        'heart_rate', 'diabetes', 'family_history', 'smoking', 'obesity',
#        'alcohol_consumption', 'exercise_hours_per_week', 'diet',
#        'previous_heart_problems', 'medication_use', 'stress_level',
#        'sedentary_hours_per_day', 'income', 'bmi', 'triglycerides',
#        'physical_activity_days_per_week', 'sleep_hours_per_day', 'country',
#        'continent', 'hemisphere', 'heart_attack_risk', '2022', '2021', 'city',
#        'remote_jobs', 'overworked_population',
#        'minimum_vacations_offered_(days)', 'vacations_taken_(days)',
#        'unemployment', 'multiple_jobholders', 'inflation',
#        'paid_parental_leave_(days)', 'covid_impact', 'covid_support',
#        'healthcare', 'access_to_mental_healthcare', 'inclusivity_&_tolerance',
#        'affordability', 'happiness,_culture_&_leisure', 'city_safety',
#        'outdoor_spaces', 'air_quality', 'wellness_and_fitness', 'total_score'],
# ...

# %%
wlb_measures = ['income','remote_jobs', 'overworked_population',
       'minimum_vacations_offered_(days)', 'vacations_taken_(days)',
       'unemployment', 'multiple_jobholders', 'inflation',
       'paid_parental_leave_(days)', 'covid_impact', 'covid_support',
       'healthcare', 'access_to_mental_healthcare', 'inclusivity_&_tolerance',
       'affordability', 'happiness,_culture_&_leisure', 'city_safety',
       'outdoor_spaces', 'air_quality', 'wellness_and_fitness', 'total_score' ]

# %%
health_measures = ['age', 'sex', 'cholesterol', 'blood_pressure',
       'heart_rate', 'diabetes', 'family_history', 'smoking', 'obesity',
       'alcohol_consumption', 'exercise_hours_per_week', 'diet',
       'previous_heart_problems', 'medication_use', 'stress_level',
       'sedentary_hours_per_day', 'bmi', 'triglycerides',
       'physical_activity_days_per_week', 'sleep_hours_per_day', 'country',
       'continent', 'hemisphere', 'heart_attack_risk','total_score']

# %%
merged_df = merged_df.dropna()

# %%
merged_df.head()
# Out:
#   patient_id  age   sex  cholesterol blood_pressure  heart_rate  diabetes  \
# 0    BMW7812   67  Male          208         158/88          72         0
# 1    CZE1114   21  Male          389         165/93          98         1
# 2    CZE1114   21  Male          389         165/93          98         1
# 3    CZE1114   21  Male          389         165/93          98         1
# 4    CZE1114   21  Male          389         165/93          98         1
#
#    family_history  smoking  obesity  ...  healthcare  \
# 0               0        1        0  ...        65.2
# 1               1        1        1  ...        96.7
# 2               1        1        1  ...        96.8
# 3               1        1        1  ...        97.2
# 4               1        1        1  ...        97.0
#
#    access_to_mental_healthcare inclusivity_&_tolerance  affordability  \
# 0                         70.2                    83.9           57.4
# ...

# %%
def country_measures(country):
    country_data = merged_df[merged_df['country'] == country]
    return country_data

# %%
country_measures('Thailand')

# %%
fig, axes = plt.subplots(nrows= 5, ncols=5, figsize = (15,20))

wlb_data = country_data[wlb_measures].melt()

wlb_data.columns = ['Measures','Values']
wlb_data.plot(kind='bar', ax= 'Measures', legend=False)
axes[0].set_title(f'WLB for {country}')
axes[0].set_ylabel('Values')

plot.tight_layout()
plt.show()

# %%
merged_df.dropna(inplace=True)
merged_df.isnull().sum()
# Out:
# age                                 0
# sex                                 0
# cholesterol                         0
# blood_pressure                      0
# diabetes                            0
# family_history                      0
# smoking                             0
# obesity                             0
# alcohol_consumption                 0
# exercise_hours_per_week             0
# diet                                0
# previous_heart_problems             0
# medication_use                      0
# stress_level                        0
# sedentary_hours_per_day             0
# income                              0
# bmi                                 0
# physical_activity_days_per_week     0
# sleep_hours_per_day                 0
# country                             0
# heart_attack_risk                   0
# 2022                                0
# 2021                                0
# remote_jobs                         0
# overworked_population               0
# ...

# %%
# Filtering for the Age range that we want to focus on (from 18 to 70 years old)
merged_df = merged_df[(merged_df['age'] >= 18 & (merged_df['age']<= 70))]

# %%
merged_df.columns
# Out:
# Index(['age', 'sex', 'cholesterol', 'blood_pressure', 'diabetes',
#        'family_history', 'smoking', 'obesity', 'alcohol_consumption',
#        'exercise_hours_per_week', 'diet', 'previous_heart_problems',
#        'medication_use', 'stress_level', 'sedentary_hours_per_day', 'income',
#        'bmi', 'physical_activity_days_per_week', 'sleep_hours_per_day',
#        'country', 'heart_attack_risk', '2022', '2021', 'remote_jobs',
#        'overworked_population', 'minimum_vacations_offered_(days)',
#        'vacations_taken_(days)', 'unemployment', 'multiple_jobholders',
#        'inflation', 'paid_parental_leave_(days)', 'covid_impact',
#        'covid_support', 'healthcare', 'access_to_mental_healthcare',
#        'affordability', 'happiness,_culture_&_leisure', 'city_safety',
#        'outdoor_spaces', 'air_quality', 'total_score'],
#       dtype='object')

# %%
merged_df.head()
# Out:
#    age   sex  cholesterol blood_pressure  diabetes  family_history  smoking  \
# 0   67  Male          208         158/88         0               0        1
# 1   21  Male          389         165/93         1               1        1
# 2   21  Male          389         165/93         1               1        1
# 3   21  Male          389         165/93         1               1        1
# 4   21  Male          389         165/93         1               1        1
#
#    obesity  alcohol_consumption  exercise_hours_per_week  ... covid_impact  \
# 0        0                    0                 4.168189  ...         63.6
# 1        1                    1                 1.813242  ...         78.5
# 2        1                    1                 1.813242  ...         77.0
# 3        1                    1                 1.813242  ...         75.3
# 4        1                    1                 1.813242  ...         75.7
#
# ...

# %%
# Starting with pairplots

wlb_group_1 = ['stress_level', 'sedentary_hours_per_day', 'income', 'physical_activity_days_per_week', 'sleep_hours_per_day', 'heart_attack_risk', 'total_score']

# %%
wlb_group_1_plot = merged_df[wlb_group_1]

# %%
sns.set(style="ticks", font_scale=1.2)
pair_plot_1 = sns.pairplot(wlb_group_1_plot, diag_kind='kde', plot_kws={'alpha':0.5})
pair_plot_1.fig.suptitle('Scatter Plot Matrix for WLB Group 1', y=1.02)

plt.show()
# Out:
# c:\Users\gisac\miniconda3\envs\nf_base\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
wlb_group_2 = ['age', 'sex','exercise_hours_per_week','stress_level', 'sedentary_hours_per_day', 'physical_activity_days_per_week', 'sleep_hours_per_day']

# %%
wlb_group_2_plot = merged_df[wlb_group_2]

# %%
sns.set(style="ticks", font_scale=1.2)
pair_plot_2 = sns.pairplot(wlb_group_2_plot, diag_kind='kde', plot_kws={'alpha':0.5})
pair_plot_2.fig.suptitle('Scatter Plot Matrix for WLB Group 2', y=1.02)
# Out:
# c:\Users\gisac\miniconda3\envs\nf_base\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.02, 'Scatter Plot Matrix for WLB Group 2')

# %%
merged_df['heart_attack_risk']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 14772    0
# 14773    0
# 14774    0
# 14775    1
# 14776    0
# Name: heart_attack_risk, Length: 11751, dtype: int64
